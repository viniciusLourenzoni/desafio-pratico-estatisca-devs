# %%
import locale
import pandas as pd
import matplotlib.pyplot as plt

# %%
locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')
# Out:
# 'pt_BR.UTF-8'

# %%
dict_faturamento = {
    'data_ref': [
        '2023-01-01', 
        '2020-02-01', 
        '2021-03-01', 
        '2022-04-01', 
        '2023-05-01',
        '2023-06-01', 
        '2020-07-01', 
        '2021-08-01', 
        '2022-09-01', 
        '2023-10-01',
        '2022-11-01', 
        '2023-12-01',
        ],
    'valor': [
        400000, 
        890000, 
        760000, 
        430000, 
        920000,
        340000, 
        800000, 
        500000, 
        200000, 
        900000,
        570000, 
        995000,
        ]
}

# %%
df_faturamento = pd.DataFrame(dict_faturamento)

# %%
df_faturamento
# Out:
#       data_ref   valor
# 0   2023-01-01  400000
# 1   2020-02-01  890000
# 2   2021-03-01  760000
# 3   2022-04-01  430000
# 4   2023-05-01  920000
# 5   2023-06-01  340000
# 6   2020-07-01  800000
# 7   2021-08-01  500000
# 8   2022-09-01  200000
# 9   2023-10-01  900000
# 10  2022-11-01  570000
# 11  2023-12-01  995000

# %%
print(df_faturamento['valor'].mean())
# Out:
# 642083.3333333334

# %%
media_vendas = df_faturamento['valor'].mean()

# %%
def formatar_moeda(valor):
    return f'R$ {valor:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')

# %%
try:
    media_vendas_formatada = locale.currency(media_vendas, grouping=True)
except (locale.Error, NameError):
    media_vendas_formatada = formatar_moeda(media_vendas)

# %%
# Média das vendas
media_vendas_formatada
# Out:
# 'R$ 642.083,33'

# %%
df_faturamento
# Out:
#       data_ref   valor
# 0   2023-01-01  400000
# 1   2020-02-01  890000
# 2   2021-03-01  760000
# 3   2022-04-01  430000
# 4   2023-05-01  920000
# 5   2023-06-01  340000
# 6   2020-07-01  800000
# 7   2021-08-01  500000
# 8   2022-09-01  200000
# 9   2023-10-01  900000
# 10  2022-11-01  570000
# 11  2023-12-01  995000

# %%
df_faturamento.plot.bar(x='data_ref', y='valor')
# Out:
# <Axes: xlabel='data_ref'>

# %%
df_faturamento['data_ref'] = pd.to_datetime(df_faturamento['data_ref'])

# %%
df_faturamento['mes'] = df_faturamento['data_ref'].dt.strftime('%B')

# %%
# Gráfico de barras vertical mostrando o mês de referência e o valor
ax = df_faturamento.plot.bar(x='mes', y='valor', legend=False)

# %%
# Gráfico de linhas mostrando o mês de referência e o valor.
df_faturamento.plot.line(x='mes', y='valor')
# Out:
# <Axes: xlabel='mes'>
